# %%
with open('soccer.txt', 'r') as f: # stores all pertinent tweet data in a file
    data = f.readlines()

# %%
stuff = data[29].split(',',3)
print stuff
# Out:
# ['@Kent4USC', 'Mon Jul 06 18:58:51 +0000 2015', '1436209131446', 'RT @ussoccer_wnt: #SheBelieved and now the #USWNT has #ThreeStars above the crest! #OneNationOneTeam http://t.co/ubpuNHZNwd\n']

# %%
a = len(data)
print "Number of tweets:", a
# Out:
# Number of tweets: 639

# %%
alltweets = open('date.txt', 'w') # creates a file filled with the tweet content of all users
problems = []
for x in range(a):
    try:
        tweet = data[x].split(',',3)
        text = tweet[3] #.split(' ') # 3 indicates the tweet of user x which is parsed into words
        alltweets.write(text)
    except:
        problems.append(x)
alltweets.close()

# %%
print len(problems)
# Out:
# 111

# %%
with open('date.txt', 'r') as tw: # finds avg number of characters per tweet
    twords = tw.readlines()

b = len(twords)
c = 0
hugelistofwords = []
for y in range(b):
    werds = twords[y].split(' ')
    c += len(werds)
    for z in werds:
        hugelistofwords.append(z)
outfile.close()
print c / b
print len(hugelistofwords)
# Out:
# 13
# 6899

# %%
print hugelistofwords
# Out:
# ['RT', '@ussoccer_wnt:', 'WATCH:', '3rd', 'start', 'special', 'tomorrow', 'with', 'the', '#USWNT', 'at', '1', 'p.m.', 'ET', '/', '10', 'a.m.', 'PT', 'on', '@FOXSports1.', '#TuneIn', 'http://t.co/CeFTm1Hi27\n', 'RT', '@CocaCola:', "America's", 'birthday', 'just', 'got', 'a', 'whole', 'lot', 'more', 'celebratory-er.', 'Congratulations', 'to', 'the', '#USWNT!', 'http://t.co/7fL0v9lawG\n', 'RT', '@nytimes:', 'The', '#USWNT', 'wins', 'third', 'Women\xe2\x80\x99s', 'World', 'Cup', 'with', 'victory', 'over', 'Japan', 'http://t.co/h4MCnjtN6y', 'http://t.co/YAGUHDpvVg\n', 'RT', '@brycecovert:', 'Tell', 'me', 'again', 'how', '#USWNT', 'deserves', 'less', 'pay', 'because', 'no', 'one', 'watches', 'http://t.co/jnOkgDLpof\n', 'RT', '@hopesolo:', 'A', 'dream', 'come', 'true!', '#USWNT', '#Champions', 'http://t.co/IYXHVXf2bS\n', 'RT', '@hopesolo:', 'A', 'dream', 'come', 'true!', '#USWNT', '#Champions', 'http://t.co/IYXHVXf2bS\n', 'I\xe2\x80\x99m', 'kicking', 'in', 'my', 'support', 'for', 'the', '#USWNT!', 'Visit', 'http://t.co/bLcdIJyY9e', '#passthelove', '#entry', 'https://t.co/3mfFhjpfT8\n', 'RT', '@ussoccer_wnt:', '#SheBelieved', 'and', 'now', 'the', '#USWNT', 'has', '#ThreeStars', 'above', 'the', 'crest!', '#OneNationOneTeam', 'http://t.co/ubpuNHZNwd\n', 'RT', '@hopesolo:', 'A', 'dream', 'come', 'true!', '#USWNT', '#Champions', 'http://t.co/IYXHVXf2bS\n', 'RT', '@nikesoccer:', 'It', 'takes', 'more', 'than', 'one', 'star', 'to', 'bring', 'home', 'your', 'third.', '#NoMaybes', '#uswnt', 'http://t.co/1SLmONMNRU\n', 'RT', '@nikesoccer:', 'It', 'takes', 'more', 'than', 'one', 'star', 'to', 'bring', 'home', 'your', 'third.', '#NoMaybes', '#uswnt', 'http://t.co/1SLmONMNRU\n', 'RT', '@JensenAckles:', "Let's", 'go', 'girls!!!!', '#WomensWorldCup', '#USWNT', 'http://t.co/VTviqHnFI0\n', 'RT', '@USTreasury:', '@ussoccer_wnt', 'Loving', 'ALL', 'the', 'suggestions', 'for', '#TheNew10', 'including', 'for', '@CarliLloyd!', 'Congrats', 'on', 'the', 'win,', '#USWNT!', '#ThreeStars', '\xe2\x80\xa6\n', 'RT', '@hopesolo:', 'A', 'dream', 'come', 'true!', '#USWNT', '#Champions', 'http://t.co/IYXHVXf2bS\n', 'RT', '@hopesolo:', 'A', 'dream', 'come', 'true!', '#USWNT', '#Champions', 'http://t.co/IYXHVXf2bS\n', 'RT', '@hopesolo:', 'A', 'dream', 'come', 'true!', '#USWNT', '#Champions', 'http://t.co/IYXHVXf2bS\n', 'RT', '@RobStoneONFOX:', 'Crowd', 'assembling', 'ahead', 'of', 'our', '#USWNT', '3rd', 'star', 'coronation', 'live', 'at', '1ET', 'on', '@FOXSports1', 'http://t.co/80zQtp2z7j\n', 'RT', '@FOXSports1:', '#USWNT', 'has', 'arrived!', 'Tune', 'in', 'to', 'FS1', 'and', 'FSGO', 'now!', 'http://t.co/yjbcCoASE8\n', 'RT', '@hopesolo:', 'A', 'dream', 'come', 'true!', '#USWNT', '#Champions', 'http://t.co/IYXHVXf2bS\n', 'RT', '@heathermitts:', 'Last', 'day', 'with', '@AriHingst', '@kelly_smith10', '@RobStoneONFOX', '@AlexiLalas', '&amp;', 'the', '#USWNT', 'as', 'we', 'unveil', 'the', '3rd', '\xf0\x9f\x8c\x9f.', 'The', 'marathon', 'is', 'o\xe2\x80\xa6\n', 'RT', '@ussoccer_wnt:', '#SheBelieved', 'and', 'now', 'the', '#USWNT', 'has', '#ThreeStars', 'above', 'the', 'crest!', '#OneNationOneTeam', 'http://t.co/ubpuNHZNwd\n', 'RT', '@TVOvermind:', "#Supernatural's", '@JensenAckles', 'and', '@jarpad', 'Took', 'the', 'Best', 'World', 'Cup', 'Photo', 'Ever:', 'http://t.co/iKB1JMuTo6', '#USWNT', 'http://t.co/na8\xe2\x80\xa6\n', 'I', 'wanna', 'be', 'her', 'some', 'day..', 'such', 'a', 'great', 'role', 'model!!', ':)\n', 'RT', '@hopesolo:', 'A', 'dream', 'come', 'true!', '#USWNT', '#Champions', 'http://t.co/IYXHVXf2bS\n', 'RT', '@UltraViolet:', 'Demand', 'that', 'U.S.', "Women's", 'soccer', 'players', 'be', 'payed', 'equally:', 'http://t.co/2vAarH6V4u', '@ussoccer_wnt', '#USWNT\n', 'RT', '@FOXSports1:', 'Your', '2015', "Women's", 'World', 'Cup', 'Champions!', '#USWNT', 'http://t.co/H5Igsoeb5A\n', 'RT', '@ussoccer_wnt:', '#SheBelieved', 'and', 'now', 'the', '#USWNT', 'has', '#ThreeStars', 'above', 'the', 'crest!', '#OneNationOneTeam', 'http://t.co/ubpuNHZNwd\n', 'RT', '@Boston2024:' ...
