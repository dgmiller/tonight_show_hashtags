# %%
with open('test.txt', 'r') as f:
    data = f.readlines()
    
print data
# Out:
# ['@rnariarty,Fri Jul 03 21:32:54 +0000 2015,1435959174382,Ordered a beer an hour ago  where is it\xe3\x83\xbd(`\xd0\x94\xc2\xb4)\xef\xbe\x89\n', '@HaywooddrinksNI,Fri Jul 03 21:32:54 +0000 2015,1435959174689,RT @hildenbrewery: @MissAlexjones @achrisevans, get down to the Hilden brewery big orangey/red Beer tent after the #theoneshow! http://t.co\xe2\x80\xa6\n', "@Maverick_Player,Fri Jul 03 21:32:54 +0000 2015,1435959174827,@HunterKillerD &gt; already been shattered. *eyes the beer* Ya gonna offer, or I stealin' yours?\n", '@justjoey33,Fri Jul 03 21:32:54 +0000 2015,1435959174915,@NASHFM1033 beer in Mexico - Kenny Chesney\n', "@TheMikeMyers,Fri Jul 03 21:32:55 +0000 2015,1435959175255,I just earned the 'Bay Crafted' badge on @untappd! http://t.co/0i0N9u7QdS #BayCrafted\n", '@xtiffany_lee,Fri Jul 03 21:32:55 +0000 2015,1435959175967,Beer before work? Why not. #GoBigOrGoHome\n', '@Donn5542,Fri Jul 03 21:32:57 +0000 2015,1435959177210,#Time to #Party - #Advertise to Millions of #People f
# ...

# %%
print data[1].split(',',3)
# Out:
# ['@HaywooddrinksNI', 'Fri Jul 03 21:32:54 +0000 2015', '1435959174689', 'RT @hildenbrewery: @MissAlexjones @achrisevans, get down to the Hilden brewery big orangey/red Beer tent after the #theoneshow! http://t.co\xe2\x80\xa6\n']
